# %% [markdown]
# # word2vec_basic

# %%
import collections
import math
import os
import random
from tempfile import gettempdir
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf
# Out:
# C:\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# ### step1 读取数据

# %%
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words."""
    with open(filename,'rb') as f:
        data=[]
        for line in f:
            col=line.decode().strip()
            for word in col:
                data.append(word)
    return data

filename='QuanSongCi.txt'
vocabulary = read_data(filename)
print('Data size', len(vocabulary))
# Out:
# Data size 1786003

# %% [markdown]
# ### step2 创建字典并将稀有数据用unk表示

# %%
vocabulary_size = 5000

def build_dataset(words, n_words):
    """Process raw inputs into a dataset."""
    count = [['UNK', -1]]
    #取词频最高的前50000个汉字加入到count中 值表示出现的次数
    count.extend(collections.Counter(words).most_common(n_words - 1))
    dictionary = dict()
    #按count顺序创建字典，key是字 value是顺序
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    #返回各个word在dictionary中的索引，如果不在dictionary的话就将其置为0，通过这样可以得到unk的个数
    for word in words:
        index = dictionary.get(word, 0)
        if index == 0:  # dictionary['UNK']
            unk_count += 1
        data.append(index)
    #重置unk的个数
    count[0][1] = unk_count
    #反转一下字典，索引在前，word在后
    reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reversed_dictionary

# Filling 4 global variables:
# data - list of codes (integers from 0 to vocabulary_size-1).
#   This is the original text but words are replaced by their codes
# count - map of words(strings) to count of occurrences
# dictionary - map of words(strings) to their codes(integers)
# reverse_dictionary - maps codes(integers) to words(strings)
data, count, dictionary, reverse_dictionary = build_dataset(vocabulary,
                                                            vocabulary_size)
#del vocabulary  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])

data_index = 0
# Out:
# Most common words (+UNK) [['UNK', 1194], ('。', 149620), ('，', 108451), ('、', 19612), ('人', 13607)]
# Sample data [1502, 1827, 39, 612, 46, 8, 110, 116, 7, 9] ['潘', '阆', '酒', '泉', '子', '（', '十', '之', '一', '）']

# %% [markdown]
# ### step3 生成训练的batch  skip-gram model

# %%
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1  # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)  # pylint: disable=redefined-builtin
  if data_index + span > len(data):
    data_index = 0
  buffer.extend(data[data_index:data_index + span])
  data_index += span
  for i in range(batch_size // num_skips):
    context_words = [w for w in range(span) if w != skip_window]
    words_to_use = random.sample(context_words, num_skips)
    for j, context_word in enumerate(words_to_use):
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[context_word]
    if data_index == len(data):
      buffer.extend(data[0:span])
      data_index = span
    else:
      buffer.append(data[data_index])
      data_index += 1
  # Backtrack a little bit to avoid skipping words in the end of a batch
  data_index = (data_index + len(data) - span) % len(data)
  return batch, labels


batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]], '->', labels[i, 0],
reverse_dictionary[labels[i, 0]])
# Out:
# 9 ） -> 40 长
# 9 ） -> 7 一
# 40 长 -> 309 忆
# 40 长 -> 9 ）
# 309 忆 -> 40 长
# 309 忆 -> 980 钱
# 980 钱 -> 656 塘
# 980 钱 -> 309 忆

# %% [markdown]
# ### step4 创建并且训练模型

# %%
batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1  # How many words to consider left and right.
num_skips = 2  # How many times to reuse an input to generate a label.
num_sampled = 64  # Number of negative examples to sample.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. These 3 variables are used only for
# displaying model accuracy, they don't affect calculation.
valid_size = 16  # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)

graph = tf.Graph()

with graph.as_default():

  # Input data.
  with tf.name_scope('inputs'):
    train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
  with tf.device('/cpu:0'):
    # Look up embeddings for inputs.
    with tf.name_scope('embeddings'):
      embeddings = tf.Variable(
          tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
      embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    with tf.name_scope('weights'):
      nce_weights = tf.Variable(
          tf.truncated_normal(
              [vocabulary_size, embedding_size],
              stddev=1.0 / math.sqrt(embedding_size)))
    with tf.name_scope('biases'):
      nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Compute the average NCE loss for the batch.
  # tf.nce_loss automatically draws a new sample of the negative labels each
  # time we evaluate the loss.
  # Explanation of the meaning of NCE loss:
  #   http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/
  with tf.name_scope('loss'):
    loss = tf.reduce_mean(
        tf.nn.nce_loss(
            weights=nce_weights,
            biases=nce_biases,
            labels=train_labels,
            inputs=embed,
            num_sampled=num_sampled,
            num_classes=vocabulary_size))

  # Add the loss value as a scalar to summary.
  tf.summary.scalar('loss', loss)

  # Construct the SGD optimizer using a learning rate of 1.0.
  with tf.name_scope('optimizer'):
    optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  # Compute the cosine similarity between minibatch examples and all embeddings.
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings,
                                            valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

  # Merge all summaries.
  merged = tf.summary.merge_all()

  # Add variable initializer.
  init = tf.global_variables_initializer()

  # Create a saver.
#saver = tf.train.Saver()

# %% [markdown]
# ### step5 开始训练

# %%
num_steps = 400000

with tf.Session(graph=graph) as session:
  # We must initialize all variables before we use them.
  init.run()
  print('Initialized')

  average_loss = 0
  for step in xrange(num_steps):
    batch_inputs, batch_labels = generate_batch(
        batch_size, num_skips, skip_window)
    feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

    # We perform one update step by evaluating the optimizer op (including it
    # in the list of returned values for session.run()
    _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += loss_val

    if step % 2000 == 0:
      if step > 0:
        average_loss /= 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step ', step, ': ', average_loss)
      average_loss = 0

    # Note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8  # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k + 1]
        log_str = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log_str = '%s %s,' % (log_str, close_word)
        print(log_str)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  193.16331481933594
# Nearest to 谁: 谌, 陲, 脆, 昉, 濑, 丞, 舒, 掏,
# Nearest to 雨: 椽, 噫, 抄, 巴, 简, 为, 畴, 讲,
# Nearest to 去: 哨, 舌, 祉, 子, 土, 阍, 软, 掀,
# Nearest to 前: 睍, 贵, 薇, 民, 偬, 膝, 汾, 辉,
# Nearest to 、: 呕, 碌, 弘, 肪, 势, 凭, 湓, 组,
# Nearest to 江: 克, 菩, 酉, 更, 孳, 璧, 滁, 值,
# Nearest to 不: 坤, 纲, 浯, 榼, 敻, 朅, 虐, 慷,
# Nearest to 天: 环, 层, 狄, 茉, 释, 虐, 的, 耦,
# Nearest to 时: 彷, 寓, 楷, 设, 涔, 舫, 垄, 邴,
# Nearest to 一: 勒, 耆, 夭, 浏, 执, 褒, 念, 亚,
# Nearest to 声: 醿, 歧, 概, 秧, 钎, 梦, 武, 鳞,
# Nearest to 是: 桓, 蓑, 蛰, 俪, 抨, ,, 停, 云,
# Nearest to 落: 柜, 量, 缘, ,, 榆, 之, 槊, 樨,
# Nearest to 空: 秀, 窅, 哨, 敻, 股, 头, 栩, 沤,
# Nearest to 自: 圻, 门, 呀, 豫, 揽, 台, 轫, 序,
# Nearest to 笑: 袴, 掣, 芽, 蟋, 鹔, 弟, 民, 媾,
# Average loss at step  2000 :  22.123752028226853
# Average loss at step  4000 :  5.287121938347816
# Average loss at step  6000 :  5.071093056559563
# Average loss at step  8000 :  4.923557130813599
# Average loss at step  10000 :  4.660349982857704
# Nearest to 谁: 脆, 谌, 丞, 都, 舒, 避, 何, 齐,
# Nearest to 雨: 椽, 趣, 噫, 业, 巴, 改, 畴, 蘸,
# Nearest to 去: 哨, 舌, 软, 子, 彤, 地, 也, 阍,
# Nearest to 前: 贵, 薇, 睍, 辉, 冻, 民, 汾, 膝,
# Nearest to 、: ，, 。, 沽, 组, 阆, 祓, 飙, 囗,
# Nearest to 江: 菩, 涧, 闹, 乞, 酉, 囗, 值, 容,
# Nearest to 不: 坤, 纲, 闺, 浯, 旬, 佑, 慷, 莹,
# Nearest to 天: 环, 层, 狄, 的, 蘸, 俊, 啼, 释,
# Nearest to 时: 寓, 彷, 设, 舫, 炎, 壶, 楷, 蔫,
# Nearest to 一: 勒, 耆, 执, 导, 遣, 玲, 设, 瞳,
# Nearest to 声: 醿, 歧, 概, 钎, 梦, 武, 秧, 称,
# Nearest to 是: 官, 停, 蓑, 更, 褪, 桓, 扉, 俪,
# Nearest to 落: 岩, 障, 量, 槊, 榆, 题, 缘, 涩,
# Nearest to 空: 秀, 麝, 等, 沤, 认, 窅, 禹, 哨,
# Nearest to 自: 门, 寞, 豫, 当, 那, 揽, 喉, 恶,
# Nearest to 笑: 袴, 芽, 弟, 咏, 掣, 宁, 续, 民,
# Average loss at step  12000 :  4.526724477291107
# Average loss at step  14000 :  4.5246115871667865
# Average loss at step  16000 :  4.469522627949715
# Average loss at step  18000 :  4.476791219949722
# Average loss at step  20000 :  4.464517208099365
# Nearest to 谁: 脆, 谌, 要, 龌, 何, 丞, 齐, □,
# Nearest to 雨: 趣, 靶, 噫, 椽, 囗, 巴, 露, 业,
# Nearest to 去: 哨, 舌, 嫌, 彤, 软, 健, 璧, 阍,
# Nearest to 前: 薇, 睍, 贵, 辉, 冻, 民, 汾, 唾,
# Nearest to 、: ，, 。, 沽, 阆, 飙, 祓, 涤, 狱,
# Nearest to 江: 菩, 涧, 溪, 璧, 乞, 囗, 滁, 隽,
# Nearest to 不: 坤, 旬, 持, 纲, 宁, 佑, 靡, 何,
# Nearest to 天: 环, 层, 狄, 蘸, 释, 啼, 茉, 俊,
# Nearest to 时: 寓, 彷, 设, 年, 效, 炎, 蔫, 且,
# Nearest to 一: 勒, 导, 执, 耆, 焉, 设, 瞳, ！,
# Nearest to 声: 醿, 概, 歧, 梦, 钎, 涛, 萨, 蔻,
# Nearest to 是: 官, 停, 待, 扉, 与, 汪, ，, 旅,
# Nearest to 落: 岩, 障, 量, 杏, 题, 槊, 榆, 樨,
# Nearest to 空: 秀, 麝, 云, 矗, 沤, 等, 置, 禹,
# Nearest to 自: 寞, 豫, 圻, 呀, 门, 窅, 那, 恶,
# Nearest to 笑: 袴, 弟, 咏, 芽, 掣, 鹔, 仰, 宁,
# Average loss at step  22000 :  4.424519703149795
# Average loss at step  24000 :  4.421284120440483
# Average loss at step  26000 :  4.433602207899094
# Average loss at step  28000 :  4.444105533957481
# Average loss at step  30000 :  4.3838177680969235
# Nearest to 谁: 要, 谌, 脆, 何, 龌, 齐, 丞, 贼,
# Nearest to 雨: 靶, 趣, 噫, 露, 囗, 椽, 祐, 巴,
# Nearest to 去: 哨, 舌, 软, 嫌, 来, 归, 健, 彤,
# Nearest to 前: 薇, 睍, 贵, 冻, 辉, 汾, 娜, 唾,
# Nearest to 、: ，, 。, ）, 飙, 囗, 阆, 祓, 涤,
# Nearest to 江: 菩, 溪, 涧, 水, 璧, 囗, 滁, 乞,
# Nearest to 不: 未, 坤, 宁, 旬, 难, 持, 待, 何,
# Nearest to 天: 环, 层, 狄, 蘸, 茉, 释, 瞬, 庄,
# Nearest to 时: 年, 彷, 寓, 设, 效, 日, 炎, 说,
# Nearest to 一: 勒, 导, 焉, 执, 耆, 设, ！, 瞳,
# Nearest to 声: 钎, 歧, 概, 醿, 涛, 梦, 蔻, 萨,
# Nearest to 是: 官, 停, 与, 掉, 在, 扉, 汪, 待,
# Nearest to 落: 岩, 杏, 障, 樨, 题, 槊, 涩, 量,
# Nearest to 空: 秀, 麝, 矗, 沤, 禹, 铗, 哨, 等,
# Nearest to 自: 圻, 呀, 豫, 寞, 门, 恶, 窅, 苹,
# Nearest to 笑: 袴, 弟, 鹔, 仰, 咏, 掣, 宁, 芽,
# Average loss at step  32000 :  4.345689019799233
# Average loss at step  34000 :  4.371085921764374
# Average loss at step  36000 :  4.405680429339409
# Average loss at step  38000 :  4.32195975625515
# Average loss at step  40000 :  4.242289422512054
# Nearest to 谁: 脆, 要, 谌, 齐, 龌, 且, 贼, 何,
# Nearest to 雨: 靶, 趣, 露, 囗, 玎, 噫, 棠, 遁,
# Nearest to 去: 哨, 归, 舌, 来, 嫌, 健, 彤, 榭,
# Nearest to 前: 睍, 薇, 冻, 娜, 贵, 辉, 汾, 底,
# Nearest to 、: ，, 。, 沽, 狱, ）, 乖, 飙, 祓,
# Nearest to 江: 溪, 菩, 涧, 水, 璧, 滁, 隽, 湖,
# Nearest to 不: 未, 难, 无, 宁, 坤, 旬, 待, 莫,
# Nearest to 天: 环, 层, 狄, 蘸, 褭, 晔, 茉, 肓,
# Nearest to 时: 年, 效, 设, 彷, 后, 处, 寓, 炎,
# Nearest to 一: 导, 勒, 执, 焉, 设, 半, 坼, 耆,
# Nearest to 声: 歧, 钎, 涛, 笛, 概, 蔻, 萨, 吹,
# Nearest to 是: 官, 在, 汪, 与, 掉, 停, 旅, 扉,
# Nearest to 落: 岩, 障, 杏, 樨, 零, 题, 涩, 量,
# Nearest to 空: 沤, 矗, 秀, 等, 麝, 哨, 禹, 铗,
# Nearest to 自: 呀, 圻, 豫, 窅, 嫣, 寞, 恶, 否,
# Nearest to 笑: 袴, 鹔, 弟, 咏, 翔, 掣, 宁, 仰,
# Average loss at step  42000 :  4.2775944805145265
# Average loss at step  44000 :  4.235788393378257
# Average loss at step  46000 :  4.261980765581131
# Average loss at step  48000 :  4.265650923848153
# Average loss at step  50000 :  4.2461900331974025
# Nearest to 谁: 要, 脆, 且, 龌, 君, 齐, 谌, 我,
# Nearest to 雨: 靶, 趣, 露, 囗, 祐, 玎, 噫, 遁,
# Nearest to 去: 归, 来, 哨, 舌, 嫌, 榭, 健, 彤,
# Nearest to 前: 睍, 薇, 娜, 冻, 底, 辉, 汾, 窝,
# Nearest to 、: ，, 。, ）, 飙, 阆, 涤, 搏, 乖,
# Nearest to 江: 溪, 菩, 涧, 水, 滁, 璧, 徂, 囗,
# Nearest to 不: 未, 难, 宁, 旬, 却, 坤, 莫, 无,
# Nearest to 天: 环, 层, 狄, 褭, 瞬, 茉, 肓, 裴,
# Nearest to 时: 年, 设, 效, 处, 后, 彷, 耆, 呵,
# Nearest to 一: 勒, 导, 半, 焉, 设, 几, 执, 坼,
# Nearest to 声: 笛, 涛, 钎, 歧, 蔻, 概, 姜, 听,
# Nearest to 是: 在, 掉, 官, 有, 与, 停, 汪, 旅,
# Nearest to 落: 樨, 岩, 障, 杏, 零, 榆, 打, 扶,
# Nearest to 空: 矗, 麝, 等, 淋, 秀, 铗, 沤, 哨,
# Nearest to 自: 呀, 圻, 嫣, 窅, 豫, 只, 否, 蕴,
# Nearest to 笑: 袴, 鹔, 咏, 弟, 翔, 仰, 饱, 掣,
# Average loss at step  52000 :  4.274704356789589
# Average loss at step  54000 :  4.31089531314373
# Average loss at step  56000 :  4.309537436723709
# Average loss at step  58000 :  4.282050041556358
# Average loss at step  60000 :  4.255914697170257
# Nearest to 谁: 脆, 要, 龌, 何, 不, 齐, 贼, 君,
# Nearest to 雨: 靶, 趣, 遁, 露, 囗, 祐, 噫, 玎,
# Nearest to 去: 来, 归, 舌, 哨, 嫌, 榭, 掬, 敦,
# Nearest to 前: 娜, 冻, 睍, 底, 薇, 窊, 将, 汾,
# Nearest to 、: ，, 。, ）, 飙, 囗, 筱, 祓, 涤,
# Nearest to 江: 溪, 菩, 水, 涧, 璧, 滁, 徂, 淮,
# Nearest to 不: 未, 难, 还, 宁, 欲, 坤, 旬, 无,
# Nearest to 天: 环, 层, 狄, 蘸, 褭, 晔, 茉, 肓,
# Nearest to 时: 年, 效, 处, 设, 曾, 后, 彷, 按,
# Nearest to 一: 半, 导, 勒, 几, 焉, 坼, 三, 坳,
# Nearest to 声: 笛, 钎, 歧, 涛, 听, 姜, 恙, 概,
# Nearest to 是: 在, 掉, 与, 官, 有, 似, 汪, 扉,
# Nearest to 落: 樨, 岩, 零, 障, 杏, 扶, 榆, 解,
# Nearest to 空: 矗, 沤, 概, 禹, 哨, 麝, 耿, 暮,
# Nearest to 自: 呀, 蕴, 圻, 带, 嫣, 恶, 门, 嚣,
# Nearest to 笑: 袴, 翔, 鹔, 仰, 弟, 醉, 饱, 宁,
# Average loss at step  62000 :  4.283885208964348
# Average loss at step  64000 :  4.314103130936623
# Average loss at step  66000 :  4.232003699064255
# Average loss at step  68000 :  4.155738068699836
# Average loss at step  70000 :  4.2172461305856705
# Nearest to 谁: 要, 不, 且, 脆, 龌, 君, 齐, 只,
# Nearest to 雨: 靶, 趣, 露, 雪, 玎, 遁, 禁, 泊,
# Nearest to 去: 归, 来, 嫌, 舌, 哨, 往, 掬, 起,
# Nearest to 前: 睍, 冻, 娜, 底, 下, 薇, 窊, 谶,
# Nearest to 、: ，, 。, ）, 狱, 飙, 筱, 涤, 阆,
# Nearest to 江: 溪, 菩, 涧, 水, 淮, , 徂, 璧,
# Nearest to 不: 未, 难, 无, 还, 坤, 莫, 欲, 宁,
# Nearest to 天: 环, 层, 狄, 晔, 褭, 肓, 蘸, 璿,
# Nearest to 时: 年, 效, 设, 曾, 后, 处, 初, 耆,
# Nearest to 一: 半, 几, 三, 坳, 导, 勒, 执, 焉,
# Nearest to 声: 笛, 钎, 歧, 涛, 听, 羌, 榔, 穟,
# Nearest to 是: 在, 掉, 有, 汪, 似, 官, 与, 过,
# Nearest to 落: 樨, 扶, 障, 零, 岩, 杏, 打, 抛,
# Nearest to 空: 矗, 沤, 概, 等, 昼, 应, 望, 铗,
# Nearest to 自: 呀, 嫣, 否, 蕴, 窅, 卺, 圻, 惟,
# Nearest to 笑: 袴, 翔, 鹔, 咏, 醉, 饱, 仰, 酬,
# Average loss at step  72000 :  4.1511798355579375
# Average loss at step  74000 :  4.189529869675637
# Average loss at step  76000 :  4.192890886485577
# Average loss at step  78000 :  4.180331157565117
# Average loss at step  80000 :  4.202077869653702
# Nearest to 谁: 龌, 且, 要, 不, 齐, 君, 那, 始,
# Nearest to 雨: 靶, 露, 趣, 禁, 雪, 遁, 玎, 祐,
# Nearest to 去: 归, 来, 舌, 嫌, 到, 哨, 榭, 往,
# Nearest to 前: 底, 睍, 娜, 下, 冻, 薇, 将, 因,
# Nearest to 、: ，, 。, ）, 搏, 筱, 飙, 知, 囗,
# Nearest to 江: 溪, 涧, 水, 淮, 菩, 徂, 滁, ,
# Nearest to 不: 未, 难, 还, 宁, 无, 坤, 莫, 始,
# Nearest to 天: 层, 环, 褭, 狄, 斫, 潮, 晔, 茉,
# Nearest to 时: 年, 效, 初, 后, 处, 设, 耆, 呵,
# Nearest to 一: 几, 半, 勒, 导, 三, 遁, 坼, 亚,
# Nearest to 声: 笛, 钎, 听, 涛, 羌, 歧, 姜, 穟,
# Nearest to 是: 在, 掉, 有, 与, 过, 似, 见, 向,
# Nearest to 落: 樨, 零, 扶, 障, 岩, 打, 杏, 梨,
# Nearest to 空: 概, 矗, 亟, 淋, 等, 昼, 耿, 铗,
# Nearest to 自: 呀, 嫣, 带, 否, 蕴, 嚣, 只, 豁,
# Nearest to 笑: 袴, 翔, 鹔, 醉, 饱, 仰, 咏, 弟,
# Average loss at step  82000 :  4.25829046690464
# Average loss at step  84000 :  4.243326327204704
# Average loss at step  86000 :  4.2255654609203335
# Average loss at step  88000 :  4.20229050719738
# Average loss at step  90000 :  4.233320872545242
# Nearest to 谁: 那, 不, 只, 龌, 始, 脆, 要, 且,
# Nearest to 雨: 靶, 趣, 禁, 露, 遁, 泊, 玎, 吒,
# Nearest to 去: 归, 来, 嫌, 舌, 到, 起, 掬, 榭,
# Nearest to 前: 底, 娜, 睍, 冻, 将, 下, 窊, 因,
# Nearest to 、: ，, 。, ）, 筱, 飙, 黉, 知, 出,
# Nearest to 江: 溪, 淮, 涧, 水, 菩, 徂, , 湖,
# Nearest to 不: 未, 难, 还, 先, 无, 坤, 宁, 欲,
# Nearest to 天: 层, 晔, 环, 褭, 狄, 暄, 灵, 云,
# Nearest to 时: 年, 效, 曾, 后, 处, 设, 按, 耆,
# Nearest to 一: 几, 半, 导, 坳, 三, 执, 勒, 胃,
# Nearest to 声: 笛, 钎, 听, 姜, 鸣, 羌, 榔, 穟,
# Nearest to 是: 在, 掉, 有, 与, 向, 过, 似, 官,
# Nearest to 落: 樨, 零, 扶, 障, 打, 杏, 榆, 岩,
# Nearest to 空: 概, 矗, 亟, 沤, 耿, 昼, 麝, 淋,
# Nearest to 自: 呀, 嫣, 蕴, 带, 攻, 嚣, 否, 卺,
# Nearest to 笑: 袴, 醉, 翔, 鹔, 仰, 饱, 共, 酬,
# Average loss at step  92000 :  4.262655355930328
# Average loss at step  94000 :  4.169703414797783
# Average loss at step  96000 :  4.120099422097206
# Average loss at step  98000 :  4.164350402355194
# Average loss at step  100000 :  4.108173609733582
# Nearest to 谁: 不, 那, 龌, 只, 始, 且, 要, 还,
# Nearest to 雨: 靶, 雪, 露, 趣, 禁, 柳, 遁, 吒,
# Nearest to 去: 归, 来, 嫌, 起, 到, 舌, 掬, 往,
# Nearest to 前: 底, 下, 睍, 娜, 冻, 薇, 窊, 因,
# Nearest to 、: ，, 。, ）, 狱, 飙, 黉, 筱, 涤,
# Nearest to 江: 溪, 淮, 水, 涧, , 菩, 徂, 湖,
# Nearest to 不: 未, 难, 还, 无, 坤, 莫, 始, 却,
# Nearest to 天: 层, 晔, 环, 狄, 暄, 褭, 璿, 帘,
# Nearest to 时: 年, 效, 设, 后, 耆, 曾, 处, 呵,
# Nearest to 一: 几, 半, 三, 执, 坼, 坳, 掾, 导,
# Nearest to 声: 笛, 听, 钎, 羌, 榔, 舻, 鸣, 涛,
# Nearest to 是: 在, 掉, 有, 过, 似, 见, 与, 被,
# Nearest to 落: 樨, 零, 扶, 障, 打, 梨, 杏, 榆,
# Nearest to 空: 概, 矗, 昼, 耿, 亟, 望, 铗, 应,
# Nearest to 自: 带, 呀, 嫣, 卺, 蕴, 否, 惟, 嚣,
# Nearest to 笑: 袴, 醉, 翔, 鹔, 共, 咏, 饱, 酬,
# Average loss at step  102000 :  4.148937842488289
# Average loss at step  104000 :  4.151083739757538
# Average loss at step  106000 :  4.13474418759346
# Average loss at step  108000 :  4.160456824183464
# Average loss at step  110000 :  4.22583012676239
# Nearest to 谁: 那, 龌, 不, 还, 始, 否, 只, 掏,
# Nearest to 雨: 靶, 露, 禁, 遁, 柳, 趣, 雪, 吒,
# Nearest to 去: 归, 来, 到, 舌, 嫌, 起, 掬, 哨,
# Nearest to 前: 睍, 底, 下, 娜, 冻, 因, 窊, 将,
# Nearest to 、: ，, 。, ）, 筱, 出, 知, 飙, 僝,
# Nearest to 江: 溪, 淮, 水, 涧, 贻, 菩, 滁, 徂,
# Nearest to 不: 未, 难, 还, 始, 欲, 宁, 无, 莫,
# Nearest to 天: 灵, 狄, 斫, 狠, 层, 璿, 儋, 褭,
# Nearest to 时: 年, 效, 耆, 处, 后, 曾, 呵, 设,
# Nearest to 一: 几, 半, 导, 胃, 三, 执, 坳, 勒,
# Nearest to 声: 笛, 钎, 听, 鸣, 羌, 舻, 榔, 穟,
# Nearest to 是: 在, 掉, 有, 过, 把, 寐, 似, 向,
# Nearest to 落: 樨, 零, 障, 扶, 梨, 杏, 江, 打,
# Nearest to 空: 概, 亟, 耿, 淋, 矗, 铗, 昼, 沤,
# Nearest to 自: 呀, 嫣, 带, 否, 颔, 蕴, 嚣, 迫,
# Nearest to 笑: 袴, 醉, 翔, 鹔, 仰, 共, 饱, 俗,
# Average loss at step  112000 :  4.199812606453896
# Average loss at step  114000 :  4.188867264032364
# Average loss at step  116000 :  4.1721357531547545
# Average loss at step  118000 :  4.203640142917633
# Average loss at step  120000 :  4.214162717103958
# Nearest to 谁: 那, 只, 不, 龌, 还, 始, 喃, 君,
# Nearest to 雨: 靶, 露, 雪, 禁, 趣, 柳, 吒, 泊,
# Nearest to 去: 来, 归, 到, 嫌, 舌, 掬, 起, 趁,
# Nearest to 前: 下, 底, 娜, 睍, 冻, 窊, 薇, 强,
# Nearest to 、: ，, 。, ）, 筱, 黉, 飙, 愁, 换,
# Nearest to 江: 淮, 溪, 水, 涧, , 湖, 迸, 贻,
# Nearest to 不: 未, 难, 还, 欲, 坤, 莫, 始, 也,
# Nearest to 天: 晔, 儋, 狄, 璿, 暄, 云, 层, 灵,
# Nearest to 时: 年, 效, 后, 曾, 耆, 处, 鸬, 设,
# Nearest to 一: 几, 半, 坳, 数, 亚, 执, 三, 胃,
# Nearest to 声: 笛, 鸣, 钎, 羌, 听, 舻, 榔, 姜,
# Nearest to 是: 在, 有, 掉, 似, 过, 与, 把, 向,
# Nearest to 落: 樨, 零, 扶, 障, 梨, 下, 打, 江,
# Nearest to 空: 概, 亟, 沤, 耿, 淋, 应, 矗, 望,
# Nearest to 自: 呀, 嫣, 攻, 蕴, 道, 嚣, 颔, 贾,
# Nearest to 笑: 袴, 醉, 翔, 鹔, 共, 仰, 饱, 绻,
# Average loss at step  122000 :  4.130911509394646
# Average loss at step  124000 :  4.099161166548729
# Average loss at step  126000 :  4.131822525858879
# Average loss at step  128000 :  4.077803572893143
# Average loss at step  130000 :  4.1109511088132855
# Nearest to 谁: 那, 只, 不, 龌, 始, 偈, 君, 喃,
# Nearest to 雨: 靶, 雪, 趣, 露, 禁, 柳, 吒, 遁,
# Nearest to 去: 归, 来, 嫌, 到, 趁, 起, 舌, 比,
# Nearest to 前: 下, 底, 睍, 冻, 因, 娜, 窊, 强,
# Nearest to 、: ，, 。, ）, 飙, 筱, 狱, 黉, 盍,
# Nearest to 江: 淮, 溪, 涧, 水, 湖, , 迸, 徂,
# Nearest to 不: 未, 难, 还, 无, 也, 始, 莫, 却,
# Nearest to 天: 暄, 空, 云, 灵, 狄, 璿, 狠, 晔,
# Nearest to 时: 年, 效, 耆, 设, 曾, 处, 后, 呵,
# Nearest to 一: 几, 半, 胃, 坳, 坼, 导, 掾, 执,
# Nearest to 声: 笛, 听, 羌, 鸣, 钎, 榔, 舻, 皪,
# Nearest to 是: 在, 掉, 有, 似, 过, 被, 寐, 见,
# Nearest to 落: 零, 樨, 扶, 梨, 障, 飞, 抛, 下,
# Nearest to 空: 概, 亟, 昼, 耿, 天, 沤, 望, 铗,
# Nearest to 自: 带, 嫣, 呀, 卺, 嚣, 倏, 颔, 否,
# Nearest to 笑: 醉, 袴, 翔, 鹔, 共, 酬, 仰, 咏,
# Average loss at step  132000 :  4.120435443878174
# Average loss at step  134000 :  4.108017581939698
# Average loss at step  136000 :  4.13606052839756
# Average loss at step  138000 :  4.1963674170970915
# Average loss at step  140000 :  4.168696764826775
# Nearest to 谁: 那, 龌, 还, 喃, 只, 始, 否, 君,
# Nearest to 雨: 靶, 露, 禁, 才, 吒, 柳, 遁, 泊,
# Nearest to 去: 归, 来, 到, 趁, 起, 舌, 往, 厢,
# Nearest to 前: 下, 底, 睍, 娜, 因, 冻, 强, 窊,
# Nearest to 、: ，, 。, ）, 筱, 飙, 狭, 涤, 僝,
# Nearest to 江: 淮, 溪, 水, 涧, 湖, 徂, 贻, 迸,
# Nearest to 不: 未, 难, 还, 始, 也, 莫, 无, 目,
# Nearest to 天: 狠, 璿, 暄, 灵, 空, 斫, 晔, 俱,
# Nearest to 时: 年, 效, 耆, 曾, 呵, 后, 鸬, 处,
# Nearest to 一: 几, 半, 娅, 导, 亚, 数, 坳, 捉,
# Nearest to 声: 笛, 鸣, 羌, 钎, 听, 舻, 榔, 穟,
# Nearest to 是: 在, 有, 掉, 把, 过, 恐, 似, 向,
# Nearest to 落: 零, 樨, 障, 扶, 梨, 下, 杏, 榆,
# Nearest to 空: 概, 亟, 耿, 淋, 沤, 铗, 昼, 矗,
# Nearest to 自: 呀, 嫣, 蕴, 颔, 嚣, 睛, 带, 倏,
# Nearest to 笑: 醉, 袴, 鹔, 翔, 共, 仰, 误, 饱,
# Average loss at step  142000 :  4.158875314235687
# Average loss at step  144000 :  4.144948639631272
# Average loss at step  146000 :  4.178049203395844
# Average loss at step  148000 :  4.183590980172157
# Average loss at step  150000 :  4.094177599668503
# Nearest to 谁: 那, 只, 还, 始, 喃, 不, 龌, 伊,
# Nearest to 雨: 靶, 雪, 吒, 露, 禁, 才, 泊, 遁,
# Nearest to 去: 归, 来, 到, 趁, 何, 过, 起, 嫌,
# Nearest to 前: 下, 底, 睍, 娜, 因, 强, 来, 冻,
# Nearest to 、: ，, 。, ）, 汜, 筱, 飙, 晼, 狱,
# Nearest to 江: 淮, 溪, 水, 涧, 湖, 湘, , 蜀,
# Nearest to 不: 未, 难, 还, 无, 欲, 也, 始, 莫,
# Nearest to 天: 暄, 云, 儋, 狠, 晔, 空, 璿, 狄,
# Nearest to 时: 年, 效, 曾, 后, 耆, 处, 柑, 设,
# Nearest to 一: 几, 半, 坳, 数, 三, 亚, 娅, 执,
# Nearest to 声: 笛, 鸣, 听, 钎, 羌, 舻, 榔, 皪,
# Nearest to 是: 在, 有, 过, 似, 掉, 把, 见, 向,
# Nearest to 落: 扶, 零, 梨, 樨, 飘, 障, 下, 残,
# Nearest to 空: 亟, 概, 沤, 但, 耿, 应, 猿, 望,
# Nearest to 自: 嫣, 攻, 道, 呀, 带, 嚣, 卺, 颔,
# Nearest to 笑: 醉, 袴, 鹔, 共, 翔, 仰, 咏, 饱,
# Average loss at step  152000 :  4.083278322458267
# Average loss at step  154000 :  4.106790802359581
# Average loss at step  156000 :  4.056511046528816
# Average loss at step  158000 :  4.082854042053222
# Average loss at step  160000 :  4.099838857233524
# Nearest to 谁: 只, 不, 还, 那, 龌, 始, 君, 喃,
# Nearest to 雨: 靶, 雪, 吒, 晴, 柳, 露, 禁, 才,
# Nearest to 去: 归, 来, 趁, 到, 坳, 嫌, 起, 滞,
# Nearest to 前: 下, 睍, 底, 因, 甬, 强, 娜, 冻,
# Nearest to 、: ，, 。, ）, 狱, 筱, 黉, 查, 飙,
# Nearest to 江: 淮, 溪, 水, 涧, 湖, 蜀, 贻, 徂,
# Nearest to 不: 未, 难, 还, 无, 也, 始, 却, 谁,
# Nearest to 天: 暄, 空, 璿, 狠, 灵, 茉, 茨, 狄,
# Nearest to 时: 年, 曾, 效, 耆, 后, 呵, 处, 设,
# Nearest to 一: 几, 半, 坳, 娅, 掾, 胃, 导, 数,
# Nearest to 声: 笛, 鸣, 羌, 听, 舻, 钎, 榔, 皪,
# Nearest to 是: 在, 有, 掉, 似, 过, 把, 被, 恐,
# Nearest to 落: 零, 扶, 樨, 梨, 障, 飘, 江, 榆,
# Nearest to 空: 概, 但, 耿, 亟, 天, 昼, 矗, 淋,
# Nearest to 自: 嫣, 带, 倏, 呀, 嚣, 卺, 豁, 颔,
# Nearest to 笑: 醉, 袴, 共, 鹔, 翔, 仰, 酬, 咏,
# Average loss at step  162000 :  4.08720589029789
# Average loss at step  164000 :  4.11939335155487
# Average loss at step  166000 :  4.168776397109031
# Average loss at step  168000 :  4.142513952493667
# Average loss at step  170000 :  4.145807958245277
# Nearest to 谁: 还, 那, 只, 不, 喃, 否, 龌, 始,
# Nearest to 雨: 靶, 露, 吒, 柳, 遁, 禁, 雪, 才,
# Nearest to 去: 归, 来, 趁, 到, 何, 坳, 厢, 送,
# Nearest to 前: 下, 底, 因, 睍, 娜, 强, 甬, 冻,
# Nearest to 、: ，, 。, ）, 筱, 飙, 黉, 霙, 说,
# Nearest to 江: 淮, 溪, 水, 涧, 湖, 蜀, 徂, 迸,
# Nearest to 不: 未, 难, 也, 还, 始, 宁, 莫, 欲,
# Nearest to 天: 狠, 暄, 璿, 空, 晔, 茉, 灵, 祛,
# Nearest to 时: 年, 效, 曾, 耆, 后, 复, 柑, 呵,
# Nearest to 一: 几, 半, 数, 娅, 胃, 坳, 两, 导,
# Nearest to 声: 笛, 鸣, 钎, 听, 羌, 舻, 哀, 皪,
# Nearest to 是: 在, 有, 把, 掉, 向, 恐, 过, 似,
# Nearest to 落: 零, 樨, 扶, 梨, 下, 杏, 飘, 障,
# Nearest to 空: 概, 亟, 耿, 猿, 但, 沤, 应, 淋,
# Nearest to 自: 带, 嫣, 颔, 嚣, 蕴, 呀, 倏, 睛,
# Nearest to 笑: 醉, 袴, 共, 翔, 鹔, 仰, 绻, 怕,
# Average loss at step  172000 :  4.12144853746891
# Average loss at step  174000 :  4.161199350953102
# Average loss at step  176000 :  4.1632816271781925
# Average loss at step  178000 :  4.071164617300034
# Average loss at step  180000 :  4.0664935700893405
# Nearest to 谁: 还, 不, 那, 喃, 只, 龌, 伊, 曾,
# Nearest to 雨: 靶, 雪, 吒, 露, 柳, 禁, 遁, 泊,
# Nearest to 去: 归, 来, 趁, 到, 何, 向, 坳, 过,
# Nearest to 前: 下, 睍, 底, 甬, 因, 强, 来, 娜,
# Nearest to 、: ，, 。, ）, 狱, 汜, 黉, 筱, 添,
# Nearest to 江: 淮, 溪, 水, 蜀, 湖, 涧, 湘, ,
# Nearest to 不: 未, 难, 还, 无, 也, 始, 欲, 谁,
# Nearest to 天: 暄, 狠, 云, 空, 晔, 儋, 懵, 璿,
# Nearest to 时: 年, 曾, 效, 耆, 后, 话, 复, 呵,
# Nearest to 一: 几, 半, 坳, 三, 数, 胃, 娅, 二,
# Nearest to 声: 笛, 鸣, 羌, 听, 舻, 钎, 哀, 榔,
# Nearest to 是: 在, 有, 似, 把, 过, 掉, 向, 恐,
# Nearest to 落: 扶, 零, 梨, 飘, 樨, 障, 下, 飞,
# Nearest to 空: 但, 概, 亟, 猿, 沤, 耿, 应, 天,
# Nearest to 自: 嫣, 倏, 岂, 卺, 带, 应, 道, 攻,
# Nearest to 笑: 醉, 袴, 鹔, 翔, 共, 咏, 趓, 仰,
# Average loss at step  182000 :  4.086865605473518
# Average loss at step  184000 :  4.0351249867677685
# Average loss at step  186000 :  4.055956927537918
# Average loss at step  188000 :  4.085124106228352
# Average loss at step  190000 :  4.067201320409775
# Nearest to 谁: 还, 那, 只, 不, 龌, 始, 否, 君,
# Nearest to 雨: 靶, 雪, 吒, 露, 才, 禁, 柳, 晴,
# Nearest to 去: 归, 来, 趁, 到, 滞, 厢, 何, 起,
# Nearest to 前: 下, 甬, 底, 睍, 因, 再, 强, 上,
# Nearest to 、: ，, 。, ）, 说, 筱, 恁, 纵, 狱,
# Nearest to 江: 淮, 溪, 水, 涧, 东, 蜀, 徂, 湖,
# Nearest to 不: 未, 还, 难, 也, 始, 却, 莫, 无,
# Nearest to 天: 暄, 狠, 空, 璿, 茨, 灵, 茉, 懵,
# Nearest to 时: 年, 耆, 曾, 效, 后, 处, 话, 复,
# Nearest to 一: 几, 半, 娅, 坳, 数, 柘, 此, 胃,
# Nearest to 声: 笛, 鸣, 羌, 听, 舻, 哀, 钎, 榔,
# Nearest to 是: 在, 把, 有, 掉, 恐, 似, 向, 过,
# Nearest to 落: 扶, 零, 樨, 梨, 障, 下, 飘, 锅,
# Nearest to 空: 但, 概, 亟, 耿, 猿, 天, 沤, 淋,
# Nearest to 自: 嫣, 带, 倏, 应, 嚣, 睛, 颔, 呀,
# Nearest to 笑: 醉, 袴, 共, 鹔, 仰, 咏, 翔, 俗,
# Average loss at step  192000 :  4.1081935541629795
# Average loss at step  194000 :  4.145144495725631
# Average loss at step  196000 :  4.12001528608799
# Average loss at step  198000 :  4.122617063045502
# Average loss at step  200000 :  4.105603373885154
# Nearest to 谁: 还, 那, 喃, 只, 不, 始, 否, 龌,
# Nearest to 雨: 靶, 吒, 柳, 才, 雪, 露, 禁, 冬,
# Nearest to 去: 归, 来, 趁, 到, 何, 坳, 滞, 厢,
# Nearest to 前: 底, 下, 睍, 因, 甬, 庶, 坦, 氎,
# Nearest to 、: ，, 。, ）, 筱, 说, 黉, 飙, 汜,
# Nearest to 江: 淮, 溪, 水, 蜀, 东, 湘, 湖, 涧,
# Nearest to 不: 未, 难, 也, 还, 始, 莫, 先, 惹,
# Nearest to 天: 狠, 暄, 空, 晔, 璿, 茉, 灵, 懵,
# Nearest to 时: 年, 曾, 效, 耆, 后, 处, 柑, 暂,
# Nearest to 一: 几, 半, 坳, 数, 娅, 胃, 两, 亚,
# Nearest to 声: 笛, 鸣, 钎, 羌, 哀, 舻, 听, 榔,
# Nearest to 是: 在, 有, 把, 恐, 似, 掉, 向, 过,
# Nearest to 落: 零, 梨, 扶, 下, 樨, 芦, 杏, 飘,
# Nearest to 空: 但, 亟, 概, 猿, 沤, 耿, 应, 天,
# Nearest to 自: 倏, 嚣, 嫣, 带, 道, 颔, 蕴, 攻,
# Nearest to 笑: 醉, 袴, 共, 鹔, 翔, 仰, 怕, 误,
# Average loss at step  202000 :  4.137666442632675
# Average loss at step  204000 :  4.1516542534828185
# Average loss at step  206000 :  4.038530312776565
# Average loss at step  208000 :  4.048221039295196
# Average loss at step  210000 :  4.078896802663803
# Nearest to 谁: 喃, 只, 不, 那, 还, 曾, 君, 始,
# Nearest to 雨: 靶, 雪, 吒, 柳, 晴, 露, 棂, 禁,
# Nearest to 去: 归, 来, 趁, 到, 何, 坳, 滞, 厢,
# Nearest to 前: 下, 底, 甬, 睍, 因, 上, 间, 中,
# Nearest to 、: ，, 。, ）, 筱, 狱, 黉, 知, 飙,
# Nearest to 江: 淮, 溪, 水, 蜀, 湖, 湘, 海, ,
# Nearest to 不: 未, 难, 也, 还, 无, 始, 却, 谁,
# Nearest to 天: 暄, 狠, 璿, 空, 云, 晔, 茉, 懵,
# Nearest to 时: 年, 曾, 耆, 效, 后, 话, 处, 复,
# Nearest to 一: 几, 半, 坳, 胃, 数, 此, 三, 亚,
# Nearest to 声: 笛, 鸣, 羌, 听, 哀, 舻, 榔, 皪,
# Nearest to 是: 在, 把, 有, 恐, 掉, 似, 见, 被,
# Nearest to 落: 零, 扶, 梨, 飘, 下, 樨, 障, 片,
# Nearest to 空: 但, 概, 耿, 亟, 沤, 猿, 应, 天,
# Nearest to 自: 嫣, 倏, 岂, 应, 嚣, 道, 卺, 带,
# Nearest to 笑: 醉, 袴, 鹔, 共, 羞, 翔, 咏, 趓,
# Average loss at step  212000 :  4.016937288999557
# Average loss at step  214000 :  4.038318365097046
# Average loss at step  216000 :  4.077736941695213
# Average loss at step  218000 :  4.052470683217049
# Average loss at step  220000 :  4.098850443959236
# Nearest to 谁: 还, 君, 那, 龌, 否, 喃, 只, 不,
# Nearest to 雨: 靶, 露, 雪, 柳, 吒, 才, 禁, 棂,
# Nearest to 去: 归, 来, 趁, 到, 何, 滞, 坳, 咱,
# Nearest to 前: 下, 底, 甬, 因, 睍, 再, 任, 来,
# Nearest to 、: ，, 。, ）, , 僝, 黉, 说, 咍,
# Nearest to 江: 淮, 溪, 水, 蜀, 涧, 湖, 湘, 矗,
# Nearest to 不: 未, 难, 还, 也, 始, 莫, 宁, 无,
# Nearest to 天: 狠, 暄, 儋, 懵, 茉, 灵, 璿, 冯,
# Nearest to 时: 年, 耆, 曾, 效, 后, 复, 话, 击,
# Nearest to 一: 几, 半, 坳, 胃, 娅, 数, 亚, 柘,
# Nearest to 声: 笛, 鸣, 羌, 听, 哀, 舻, 钎, 榔,
# Nearest to 是: 在, 把, 恐, 有, 掉, 过, 见, 似,
# Nearest to 落: 零, 梨, 飘, 扶, 樨, 堕, 下, 杏,
# Nearest to 空: 但, 猿, 概, 耿, 亟, 沤, 截, 应,
# Nearest to 自: 嫣, 倏, 呀, 嚣, 应, 带, 睛, 豁,
# Nearest to 笑: 醉, 袴, 鹔, 共, 仰, 俗, 羞, 趓,
# Average loss at step  222000 :  4.124363530516624
# Average loss at step  224000 :  4.108374126076698
# Average loss at step  226000 :  4.106960419535637
# Average loss at step  228000 :  4.090556298375129
# Average loss at step  230000 :  4.12613154566288
# Nearest to 谁: 那, 喃, 还, 只, 龌, 不, 否, 始,
# Nearest to 雨: 靶, 吒, 露, 禁, 晴, 遁, 雪, 柳,
# Nearest to 去: 归, 来, 趁, 到, 何, 坳, 住, 滞,
# Nearest to 前: 下, 甬, 底, 因, 睍, 庶, 任, 间,
# Nearest to 、: ，, 。, ）, 筱, 黉, 说, 绾, 霙,
# Nearest to 江: 淮, 溪, 水, 蜀, 湖, 湘, 东, 矗,
# Nearest to 不: 未, 难, 也, 还, 始, 无, 惹, 欲,
# Nearest to 天: 狠, 暄, 璿, 云, 茉, 晔, 茨, 儋,
# Nearest to 时: 年, 曾, 效, 耆, 后, 鸬, 番, 处,
# Nearest to 一: 几, 半, 坳, 两, 胃, 数, 娅, 三,
# Nearest to 声: 笛, 鸣, 羌, 钎, 哀, 舻, 皪, 榔,
# Nearest to 是: 在, 有, 把, 恐, 似, 向, 掉, 见,
# Nearest to 落: 零, 梨, 飘, 堕, 杏, 樨, 绥, 残,
# Nearest to 空: 但, 亟, 猿, 沤, 耿, 概, 谩, 拭,
# Nearest to 自: 嫣, 倏, 道, 呀, 攻, 岂, 蕴, 豁,
# Nearest to 笑: 醉, 袴, 鹔, 共, 仰, 翔, 误, 俗,
# Average loss at step  232000 :  4.132498443245888
# Average loss at step  234000 :  4.0243531289100645
# Average loss at step  236000 :  4.026885252833367
# Average loss at step  238000 :  4.071656710028648
# Average loss at step  240000 :  4.0033235863447185
# Nearest to 谁: 那, 喃, 不, 只, 始, 龌, 还, 肯,
# Nearest to 雨: 靶, 雪, 柳, 露, 吒, 晴, 棂, 遁,
# Nearest to 去: 归, 趁, 来, 到, 何, 随, 坳, 向,
# Nearest to 前: 甬, 下, 底, 睍, 因, 中, 任, 再,
# Nearest to 、: ，, 。, ）, 黉, 筱, 狱, 纵, 出,
# Nearest to 江: 淮, 溪, 水, 蜀, 湖, 派, 海, 湘,
# Nearest to 不: 未, 难, 无, 也, 还, 谁, 始, 却,
# Nearest to 天: 暄, 狠, 璿, 空, 晔, 云, 帘, 懵,
# Nearest to 时: 年, 耆, 曾, 效, 番, 后, 话, 处,
# Nearest to 一: 几, 半, 胃, 坳, 此, 数, 娅, 执,
# Nearest to 声: 笛, 鸣, 羌, 听, 哀, 榔, 语, 舻,
# Nearest to 是: 在, 有, 恐, 似, 掉, 把, 个, 向,
# Nearest to 落: 零, 梨, 飘, 堕, 片, 下, 樨, 井,
# Nearest to 空: 但, 概, 耿, 猿, 亟, 沤, 天, 谩,
# Nearest to 自: 嫣, 倏, 带, 应, 呀, 岂, 共, 卺,
# Nearest to 笑: 醉, 袴, 共, 鹔, 羞, 趓, 咏, 翔,
# Average loss at step  242000 :  4.022374811351299
# Average loss at step  244000 :  4.057194759011269
# Average loss at step  246000 :  4.0416572920084
# Average loss at step  248000 :  4.086599810838699
# Average loss at step  250000 :  4.110971470832824
# Nearest to 谁: 那, 否, 喃, 还, 龌, 不, 君, 始,
# Nearest to 雨: 靶, 露, 柳, 吒, 雪, 晴, 冬, 棂,
# Nearest to 去: 归, 来, 趁, 坳, 到, 滞, 何, 咱,
# Nearest to 前: 甬, 因, 下, 底, 睍, 氎, 坦, 任,
# Nearest to 、: ，, 。, ）, 出, 霙, 僝, 汜, ,
# Nearest to 江: 淮, 溪, 水, 蜀, 湖, 湘, 东, 矗,
# Nearest to 不: 未, 难, 也, 始, 莫, 还, 宁, 苜,
# Nearest to 天: 狠, 暄, 云, 璿, 冯, 懵, 灵, 儋,
# Nearest to 时: 年, 耆, 曾, 效, 话, 场, 暇, 番,
# Nearest to 一: 几, 半, 胃, 娅, 两, 坳, 数, 此,
# Nearest to 声: 笛, 鸣, 哀, 羌, 舻, 钎, 语, 听,
# Nearest to 是: 在, 有, 恐, 把, 掉, 似, 比, 非,
# Nearest to 落: 零, 堕, 梨, 飘, 绥, 障, 樨, 下,
# Nearest to 空: 但, 猿, 亟, 概, 耿, 沤, 天, 截,
# Nearest to 自: 倏, 嫣, 豁, 睛, 带, 颔, 呀, 应,
# Nearest to 笑: 醉, 袴, 共, 鹔, 俗, 趓, 仰, 羞,
# Average loss at step  252000 :  4.089952662348748
# Average loss at step  254000 :  4.094961792349816
# Average loss at step  256000 :  4.083894384741783
# Average loss at step  258000 :  4.114130114555359
# Average loss at step  260000 :  4.117918771505356
# Nearest to 谁: 喃, 那, 还, 只, 肯, 龌, 始, 君,
# Nearest to 雨: 靶, 露, 柳, 吒, 雪, 嘻, 冬, 棂,
# Nearest to 去: 归, 来, 趁, 到, 何, 坳, 住, 厢,
# Nearest to 前: 甬, 下, 底, 因, 睍, 侧, 庶, 氎,
# Nearest to 、: ，, 。, ）, 黉, 筱, 于, 汜, 说,
# Nearest to 江: 淮, 溪, 水, 蜀, 湖, 湘, 海, 派,
# Nearest to 不: 未, 难, 欲, 还, 也, 莫, 惹, 始,
# Nearest to 天: 暄, 狠, 儋, 茉, 璿, 空, 归, 冯,
# Nearest to 时: 年, 曾, 耆, 效, 后, 柑, 余, 番,
# Nearest to 一: 几, 半, 胃, 坳, 数, 亚, 娅, 柘,
# Nearest to 声: 笛, 鸣, 哀, 钎, 羌, 听, 榔, 闻,
# Nearest to 是: 在, 有, 似, 把, 恐, 向, 被, 掉,
# Nearest to 落: 零, 残, 堕, 下, 芦, 樨, 梨, 绥,
# Nearest to 空: 但, 亟, 猿, 沤, 谩, 耿, 概, 应,
# Nearest to 自: 嫣, 倏, 岂, 呀, 攻, 嚣, 豁, 道,
# Nearest to 笑: 醉, 袴, 共, 鹔, 怕, 羞, 俗, 仰,
# Average loss at step  262000 :  4.004445449352264
# Average loss at step  264000 :  4.023943763494492
# Average loss at step  266000 :  4.052933912396431
# Average loss at step  268000 :  3.9963869599103927
# Average loss at step  270000 :  4.010997635185719
# Nearest to 谁: 那, 只, 喃, 不, 龌, 还, 君, 始,
# Nearest to 雨: 靶, 雪, 柳, 吒, 露, 棂, 晴, 又,
# Nearest to 去: 归, 趁, 来, 到, 滞, 向, 坳, 厢,
# Nearest to 前: 甬, 下, 底, 睍, 因, 中, 侧, 任,
# Nearest to 、: ，, 。, ）, 黉, 狱, □, 筱, 飙,
# Nearest to 江: 淮, 溪, 水, 蜀, 湖, □, 海, 湘,
# Nearest to 不: 未, 难, 也, 无, 还, 却, 莫, 始,
# Nearest to 天: 狠, 暄, 茉, 空, 茨, 云, 璿, 霄,
# Nearest to 时: 年, 曾, 耆, 效, 话, 处, 番, 击,
# Nearest to 一: 几, 半, 胃, 坳, 此, 娅, 数, 柘,
# Nearest to 声: 笛, 听, 鸣, 哀, 羌, 榔, 闻, 语,
# Nearest to 是: 在, 有, 恐, 似, 把, 掉, 个, 向,
# Nearest to 落: 零, 堕, 飘, 井, 梨, 片, 绥, 残,
# Nearest to 空: 但, 猿, 概, 谩, 亟, 耿, 沤, 天,
# Nearest to 自: 嫣, 倏, 岂, 带, 呀, 嚣, 颔, 豁,
# Nearest to 笑: 醉, 袴, 共, 羞, 鹔, 仰, 煦, 俗,
# Average loss at step  272000 :  4.037746904611588
# Average loss at step  274000 :  4.038605864167214
# Average loss at step  276000 :  4.083153475999832
# Average loss at step  278000 :  4.092470920085907
# Average loss at step  280000 :  4.085331708788872
# Nearest to 谁: 那, 还, 喃, 否, 龌, 只, 君, 不,
# Nearest to 雨: 靶, 露, 柳, 吒, 又, 雪, 冬, 遁,
# Nearest to 去: 归, 趁, 来, 到, 住, 滞, 厢, 向,
# Nearest to 前: 甬, 因, 下, 底, 任, 睍, 再, 侧,
# Nearest to 、: ，, 。, ）, 筱, 狱, 飙, 僝, 霙,
# Nearest to 江: 淮, 溪, 水, 湖, 蜀, 湘, 矗, 海,
# Nearest to 不: 未, 难, 还, 也, 莫, 圜, 始, 惹,
# Nearest to 天: 狠, 暄, 空, 威, 璿, 冯, 祛, 茉,
# Nearest to 时: 年, 曾, 耆, 效, 柑, 场, 话, 余,
# Nearest to 一: 几, 半, 数, 娅, 胃, 坳, 片, 亚,
# Nearest to 声: 笛, 鸣, 哀, 听, 舻, 羌, 语, 钎,
# Nearest to 是: 在, 有, 把, 恐, 掉, 向, 比, 非,
# Nearest to 落: 堕, 零, 芦, 飞, 飘, 梨, 绥, 井,
# Nearest to 空: 猿, 亟, 沤, 概, 但, 天, 耿, 谩,
# Nearest to 自: 嫣, 倏, 睛, 豁, 应, 呀, 苹, 嚣,
# Nearest to 笑: 醉, 袴, 共, 鹔, 羞, 怕, 误, 俗,
# Average loss at step  282000 :  4.08031478202343
# Average loss at step  284000 :  4.077991665005684
# Average loss at step  286000 :  4.104369265913963
# Average loss at step  288000 :  4.1046328999996184
# Average loss at step  290000 :  3.9842453384399414
# Nearest to 谁: 喃, 那, 不, 只, 还, 肯, 君, 龌,
# Nearest to 雨: 靶, 吒, 雪, 露, 棂, 柳, 晴, 又,
# Nearest to 去: 归, 来, 趁, 何, 到, 随, 暮, 坳,
# Nearest to 前: 甬, 下, 因, 底, 来, 睍, 旧, 今,
# Nearest to 、: ，, 。, 添, ）, 黉, 人, 花, 纵,
# Nearest to 江: 淮, 溪, 水, 湖, 蜀, 湘, 海, 派,
# Nearest to 不: 未, 无, 难, 还, 也, 莫, 欲, 惹,
# Nearest to 天: 暄, 云, 狠, 空, 茉, 霄, 儋, 晔,
# Nearest to 时: 年, 曾, 耆, 效, 后, 番, 似, 处,
# Nearest to 一: 几, 半, 坳, 数, 胃, 片, 三, 执,
# Nearest to 声: 笛, 哀, 鸣, 听, 羌, 舻, 闻, 皪,
# Nearest to 是: 在, 恐, 有, 似, 把, 被, 向, 掉,
# Nearest to 落: 飘, 堕, 零, 芦, 残, 下, 梨, 飞,
# Nearest to 空: 但, 谩, 沤, 亟, 猿, 应, 天, 耿,
# Nearest to 自: 嫣, 倏, 岂, 应, 豁, 攻, 呀, 嚣,
# Nearest to 笑: 醉, 鹔, 袴, 共, 羞, 俗, 怕, 趓,
# Average loss at step  292000 :  4.023870401978493
# Average loss at step  294000 :  4.041619259357453
# Average loss at step  296000 :  3.985110004425049
# Average loss at step  298000 :  4.009925608277321
# Average loss at step  300000 :  4.017357882857323
# Nearest to 谁: 那, 还, 只, 龌, 不, 喃, 否, 肯,
# Nearest to 雨: 靶, 雪, 柳, 吒, 又, 晴, 露, 棂,
# Nearest to 去: 归, 趁, 来, 滞, 坳, 何, 向, 到,
# Nearest to 前: 甬, 底, 因, 睍, 下, 任, 中, 侧,
# Nearest to 、: ，, 。, ）, 黉, 狱, , 说, 纵,
# Nearest to 江: 淮, 溪, 水, 湖, 蜀, 东, 湘, 岭,
# Nearest to 不: 未, 难, 也, 无, 还, 莫, 谁, 却,
# Nearest to 天: 暄, 空, 狠, 茉, 茨, 璿, 冯, 威,
# Nearest to 时: 年, 耆, 曾, 番, 效, 场, 处, 话,
# Nearest to 一: 几, 半, 坳, 胃, 娅, 数, 千, 片,
# Nearest to 声: 笛, 鸣, 哀, 听, 闻, 舻, 羌, 榔,
# Nearest to 是: 在, 有, 恐, 把, 掉, 似, 被, 向,
# Nearest to 落: 堕, 零, 飘, 梨, 下, 绥, 井, 咽,
# Nearest to 空: 但, 猿, 谩, 天, 亟, 沤, 截, 概,
# Nearest to 自: 嫣, 倏, 睛, 带, 豁, 岂, 应, 呀,
# Nearest to 笑: 醉, 袴, 共, 鹔, 羞, 俗, 趓, 仰,
# Average loss at step  302000 :  4.034140873432159
# Average loss at step  304000 :  4.075138853430748
# Average loss at step  306000 :  4.080846433401108
# Average loss at step  308000 :  4.075364969849587
# Average loss at step  310000 :  4.065401858568191
# Nearest to 谁: 还, 那, 喃, 否, 肯, 只, 龌, 巑,
# Nearest to 雨: 靶, 柳, 吒, 露, 棂, 雪, 又, 冬,
# Nearest to 去: 归, 趁, 来, 何, 厢, 住, 到, 坳,
# Nearest to 前: 甬, 因, 下, 底, 任, 睍, 再, 氎,
# Nearest to 、: ，, 。, ）, 黉, 说, 霙, 筱, 隔,
# Nearest to 江: 淮, 水, 溪, 湖, 湘, 蜀, 海, 派,
# Nearest to 不: 未, 难, 也, 还, 始, 惹, 易, 莫,
# Nearest to 天: 狠, 暄, 祛, 空, 茉, 晔, 璿, 威,
# Nearest to 时: 年, 曾, 耆, 效, 番, 族, 处, 柑,
# Nearest to 一: 几, 半, 数, 坳, 娅, 胃, 两, 柘,
# Nearest to 声: 笛, 鸣, 哀, 钎, 听, 舻, 羌, 榔,
# Nearest to 是: 在, 有, 把, 恐, 似, 向, 被, 掉,
# Nearest to 落: 堕, 零, 芦, 梨, 井, 绥, 下, 坠,
# Nearest to 空: 猿, 但, 谩, 沤, 亟, 概, 天, 应,
# Nearest to 自: 应, 嫣, 倏, 带, 睛, 豁, 呀, 嚣,
# Nearest to 笑: 醉, 共, 袴, 鹔, 羞, 误, 怕, 仰,
# Average loss at step  312000 :  4.076076407670975
# Average loss at step  314000 :  4.098257328271866
# Average loss at step  316000 :  4.089862702488899
# Average loss at step  318000 :  3.9773033211231232
# Average loss at step  320000 :  4.015848439216613
# Nearest to 谁: 喃, 那, 还, 只, 不, 君, 肯, 龌,
# Nearest to 雨: 靶, 吒, 雪, 露, 芭, 棂, 晴, 柳,
# Nearest to 去: 归, 趁, 来, 到, 何, 坳, 滞, 过,
# Nearest to 前: 甬, 因, 下, 底, 睍, 再, 中, 侧,
# Nearest to 、: ，, 。, ）, 花, 纵, 黉, 筱, 逐,
# Nearest to 江: 淮, 溪, 水, 湖, 蜀, 海, 湘, 派,
# Nearest to 不: 未, 难, 还, 无, 也, 始, 惹, 莫,
# Nearest to 天: 暄, 云, 狠, 霄, 空, 归, 懵, 璿,
# Nearest to 时: 年, 曾, 耆, 番, 效, 话, 后, 似,
# Nearest to 一: 几, 半, 坳, 数, 三, 胃, 娅, 千,
# Nearest to 声: 笛, 哀, 鸣, 听, 闻, 语, 舻, 榔,
# Nearest to 是: 在, 恐, 有, 把, 似, 掉, 向, 过,
# Nearest to 落: 堕, 零, 飘, 梨, 绥, 漂, 芦, 咽,
# Nearest to 空: 但, 谩, 猿, 沤, 亟, 枉, 应, 天,
# Nearest to 自: 倏, 嫣, 岂, 应, 豁, 带, 卺, 意,
# Nearest to 笑: 醉, 鹔, 袴, 羞, 共, 趓, 俗, 妒,
# Average loss at step  322000 :  4.029181549191475
# Average loss at step  324000 :  3.9805540772676467
# Average loss at step  326000 :  3.9880379654169085
# Average loss at step  328000 :  4.013564976096153
# Average loss at step  330000 :  4.02379298210144
# Nearest to 谁: 还, 喃, 龌, 那, 我, 否, 君, 只,
# Nearest to 雨: 靶, 露, 雪, 柳, 吒, 岛, 雷, 棂,
# Nearest to 去: 归, 趁, 来, 滞, 访, 到, 住, 厢,
# Nearest to 前: 甬, 底, 因, 再, 下, 睍, 侧, 任,
# Nearest to 、: ，, 。, ）, 说, , 狱, 便, 黉,
# Nearest to 江: 淮, 溪, 水, 湖, 蜀, 东, 湘, 波,
# Nearest to 不: 未, 难, 也, 惹, 还, 莫, 始, 无,
# Nearest to 天: 狠, 暄, 冯, 懵, 茉, 空, 威, 茨,
# Nearest to 时: 年, 耆, 番, 曾, 处, 效, 族, 场,
# Nearest to 一: 几, 半, 娅, 胃, 柘, 坳, 此, 片,
# Nearest to 声: 笛, 哀, 鸣, 羌, 听, 闻, 舻, 榔,
# Nearest to 是: 在, 恐, 把, 有, 掉, 被, 似, 要,
# Nearest to 落: 堕, 零, 飘, 绥, 芦, 片, 咽, 梨,
# Nearest to 空: 但, 猿, 谩, 截, 亟, 沤, 天, 概,
# Nearest to 自: 倏, 嫣, 豁, 睛, 应, 带, 岂, 呀,
# Nearest to 笑: 醉, 袴, 羞, 共, 鹔, 俗, 仰, 趓,
# Average loss at step  332000 :  4.073220248818398
# Average loss at step  334000 :  4.063298903822899
# Average loss at step  336000 :  4.0733446499109265
# Average loss at step  338000 :  4.055019337534905
# Average loss at step  340000 :  4.063832149982453
# Nearest to 谁: 还, 那, 不, 喃, 只, 肯, 我, 龌,
# Nearest to 雨: 靶, 吒, 雪, 冬, 柳, 露, 棂, 春,
# Nearest to 去: 归, 趁, 来, 何, 滞, 暮, 厢, 坳,
# Nearest to 前: 甬, 因, 睍, 任, 底, 下, 侧, 再,
# Nearest to 、: ，, 。, ）, 说, 黉, , 僝, 筱,
# Nearest to 江: 淮, 溪, 水, 湖, 蜀, 湘, 东, 派,
# Nearest to 不: 未, 难, 也, 还, 始, 莫, 惹, 谁,
# Nearest to 天: 狠, 暄, 云, 茉, 空, 璿, 晔, 霄,
# Nearest to 时: 年, 曾, 番, 耆, 效, 处, 后, 柑,
# Nearest to 一: 几, 半, 坳, 数, 娅, 胃, 两, 柘,
# Nearest to 声: 哀, 笛, 鸣, 钎, 羌, 阕, 榔, 舻,
# Nearest to 是: 在, 有, 把, 恐, 似, 向, 被, 掉,
# Nearest to 落: 堕, 零, 芦, 漂, 绥, 井, 梨, 飘,
# Nearest to 空: 谩, 猿, 但, 亟, 沤, 天, 截, 枉,
# Nearest to 自: 倏, 嫣, 应, 岂, 豁, 嚣, 带, 呀,
# Nearest to 笑: 醉, 袴, 鹔, 羞, 俗, 趓, 共, 误,
# Average loss at step  342000 :  4.087768216252327
# Average loss at step  344000 :  4.082094171047211
# Average loss at step  346000 :  3.969784633398056
# Average loss at step  348000 :  3.998074225783348
# Average loss at step  350000 :  4.028823790788651
# Nearest to 谁: 那, 不, 喃, 只, 还, 肯, 君, 曾,
# Nearest to 雨: 靶, 雪, 柳, 露, 吒, 棂, 晴, 又,
# Nearest to 去: 归, 来, 趁, 到, 住, 过, 何, 滞,
# Nearest to 前: 甬, 因, 底, 下, 侧, 睍, 再, 任,
# Nearest to 、: ，, 。, ）, 黉, 狱, 筱, 逐, 纵,
# Nearest to 江: 淮, 溪, 水, 湖, 蜀, 岭, 海, 派,
# Nearest to 不: 未, 难, 也, 还, 谁, 惹, 始, 无,
# Nearest to 天: 暄, 狠, 空, 璿, 懵, 云, 茉, 威,
# Nearest to 时: 年, 曾, 番, 耆, 处, 话, 效, 场,
# Nearest to 一: 几, 半, 胃, 此, 坳, 数, 片, 娅,
# Nearest to 声: 哀, 笛, 鸣, 听, 闻, 榔, 羌, 舻,
# Nearest to 是: 在, 恐, 似, 有, 把, 掉, 向, 见,
# Nearest to 落: 堕, 飘, 梨, 井, 颅, 残, 梧, 芦,
# Nearest to 空: 但, 谩, 猿, 沤, 截, 亟, 天, 耿,
# Nearest to 自: 嫣, 倏, 应, 岂, 豁, 未, 带, 始,
# Nearest to 笑: 醉, 羞, 袴, 鹔, 趓, 共, 俗, 妒,
# Average loss at step  352000 :  3.96736254131794
# Average loss at step  354000 :  3.9804421947002413
# Average loss at step  356000 :  4.005820386290551
# Average loss at step  358000 :  4.012402357935906
# Average loss at step  360000 :  4.07467942750454
# Nearest to 谁: 还, 龌, 喃, 那, 肯, 君, 否, 不,
# Nearest to 雨: 靶, 柳, 露, 雪, 岛, 棂, 霭, 冬,
# Nearest to 去: 趁, 来, 归, 咱, 滞, 坳, 何, 访,
# Nearest to 前: 甬, 底, 因, 侧, 下, 今, 任, 睍,
# Nearest to 、: ，, 。, ）, , 筱, 僝, 说, 咍,
# Nearest to 江: 淮, 溪, 水, 湖, 蜀, 湘, 派, 东,
# Nearest to 不: 未, 难, 始, 也, 莫, 还, 苜, 惹,
# Nearest to 天: 狠, 暄, 茉, 冯, 璿, 祛, 懵, 晔,
# Nearest to 时: 年, 番, 曾, 耆, 效, 场, 击, 族,
# Nearest to 一: 几, 半, 胃, 数, 坳, 片, 娅, 此,
# Nearest to 声: 笛, 哀, 鸣, 听, 榔, 闻, 语, 舻,
# Nearest to 是: 在, 恐, 把, 有, 似, 掉, 被, 过,
# Nearest to 落: 堕, 飘, 梧, 零, 漂, 梨, 片, 芦,
# Nearest to 空: 猿, 但, 谩, 沤, 截, 亟, 枉, 耿,
# Nearest to 自: 倏, 嫣, 豁, 睛, 应, 性, 颔, 虽,
# Nearest to 笑: 醉, 袴, 羞, 鹔, 趓, 俗, 共, 叹,
# Average loss at step  362000 :  4.053969985604287
# Average loss at step  364000 :  4.07479225230217
# Average loss at step  366000 :  4.043778998374939
# Average loss at step  368000 :  4.057120193243026
# Average loss at step  370000 :  4.080496531486511
# Nearest to 谁: 那, 喃, 还, 只, 不, 肯, 龌, 否,
# Nearest to 雨: 靶, 柳, 吒, 雪, 棂, 露, 霭, 晴,
# Nearest to 去: 归, 趁, 来, 何, 到, 滞, 住, 坳,
# Nearest to 前: 甬, 因, 侧, 底, 今, 下, 任, 睍,
# Nearest to 、: ，, 。, ）, 黉, 片, 说, 筱, 花,
# Nearest to 江: 淮, 溪, 水, 湖, 湘, 蜀, 派, 矗,
# Nearest to 不: 未, 难, 也, 还, 惹, 谁, 无, 始,
# Nearest to 天: 狠, 暄, 威, 晔, 璿, 空, 茉, 云,
# Nearest to 时: 年, 曾, 番, 耆, 族, 后, 效, 柑,
# Nearest to 一: 几, 半, 数, 胃, 坳, 娅, 片, 两,
# Nearest to 声: 哀, 笛, 鸣, 舻, 闻, 听, 钎, 羌,
# Nearest to 是: 在, 有, 恐, 似, 把, 向, 被, 掉,
# Nearest to 落: 堕, 飘, 梧, 残, 漂, 坠, 零, 绥,
# Nearest to 空: 谩, 猿, 沤, 但, 亟, 截, 漫, 枉,
# Nearest to 自: 嫣, 倏, 豁, 带, 岂, 呀, 应, 攻,
# Nearest to 笑: 醉, 袴, 鹔, 羞, 趓, 俗, 共, 仰,
# Average loss at step  372000 :  4.07624622631073
# Average loss at step  374000 :  3.9590806492567063
# Average loss at step  376000 :  3.9912144684791566
# Average loss at step  378000 :  4.018801661372184
# Average loss at step  380000 :  3.974909561872482
# Nearest to 谁: 那, 不, 只, 喃, 肯, 还, 龌, 君,
# Nearest to 雨: 靶, 雪, 柳, 棂, 芭, 露, 霭, 晴,
# Nearest to 去: 归, 趁, 来, 到, 访, 何, 向, 厢,
# Nearest to 前: 甬, 因, 底, 中, 睍, 下, 再, 今,
# Nearest to 、: ，, 。, ）, 黉, 狱, 输, 出, 查,
# Nearest to 江: 淮, 溪, 水, 湖, 蜀, 湘, 派, 岭,
# Nearest to 不: 未, 难, 无, 也, 却, 谁, 莫, 岂,
# Nearest to 天: 暄, 狠, 空, 璿, 威, 懵, 晔, 匝,
# Nearest to 时: 年, 曾, 番, 耆, 族, 处, 效, 话,
# Nearest to 一: 几, 半, 胃, 坳, 此, 数, 娅, 片,
# Nearest to 声: 哀, 笛, 听, 闻, 鸣, 语, 羌, 榔,
# Nearest to 是: 在, 恐, 有, 似, 掉, 把, 个, 过,
# Nearest to 落: 堕, 飘, 坠, 井, 片, 零, 残, 颅,
# Nearest to 空: 谩, 但, 猿, 沤, 天, 漫, 截, 亟,
# Nearest to 自: 嫣, 倏, 应, 带, 豁, 赖, 泪, 虽,
# Nearest to 笑: 醉, 袴, 羞, 鹔, 共, 趓, 俗, 误,
# Average loss at step  382000 :  3.97055601733923
# Average loss at step  384000 :  3.9937828587293627
# Average loss at step  386000 :  4.006154864668846
# Average loss at step  388000 :  4.061048772335052
# Average loss at step  390000 :  4.043960371494293
# Nearest to 谁: 那, 否, 还, 喃, 不, 龌, 只, 肯,
# Nearest to 雨: 靶, 柳, 露, 又, 棂, 霭, 晴, 芭,
# Nearest to 去: 趁, 归, 来, 访, 咱, 滞, 厢, 故,
# Nearest to 前: 甬, 因, 侧, 任, 氎, 底, 今, 再,
# Nearest to 、: ，, 。, ）, 霙, 挹, 片, 输, 任,
# Nearest to 江: 淮, 溪, 水, 湖, 湘, 蜀, 矗, 峙,
# Nearest to 不: 未, 难, 莫, 也, 始, 岂, 焉, 谁,
# Nearest to 天: 狠, 暄, 威, 云, 匝, 伛, 茨, 空,
# Nearest to 时: 年, 曾, 耆, 番, 族, 舷, 效, 场,
# Nearest to 一: 几, 胃, 半, 数, 此, 娅, 坳, 柘,
# Nearest to 声: 哀, 笛, 鸣, 榔, 舻, 听, 羌, 钎,
# Nearest to 是: 在, 恐, 有, 把, 似, 比, 道, 非,
# Nearest to 落: 堕, 飘, 坠, 零, 漂, 梧, 绥, 井,
# Nearest to 空: 猿, 谩, 沤, 但, 亟, 截, 耿, 纵,
# Nearest to 自: 嫣, 倏, 豁, 睛, 赖, 未, 性, 带,
# Nearest to 笑: 醉, 袴, 俗, 鹔, 趓, 羞, 共, 叹,
# Average loss at step  392000 :  4.067767951011658
# Average loss at step  394000 :  4.0399252310991285
# Average loss at step  396000 :  4.0525751662254335
# Average loss at step  398000 :  4.0754913388490674

# %% [markdown]
# ### step6 可视化

# %%
# Step 6: Visualize the embeddings.


# pylint: disable=missing-docstring
# Function to draw visualization of distance between embeddings.
def plot_with_labels(low_dim_embs, labels, filename):
  assert low_dim_embs.shape[0] >= len(labels), 'More labels than embeddings'
  plt.figure(figsize=(18, 18))  # in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i, :]
    plt.scatter(x, y)
    plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')

  plt.savefig(filename)

try:
  # pylint: disable=g-import-not-at-top
  from sklearn.manifold import TSNE
  import matplotlib.pyplot as plt

  plt.rcParams["font.sans-serif"] = ["SimHei"]
  plt.rcParams['axes.unicode_minus'] = False

  tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
  plot_only = 500
  low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
  labels = [reverse_dictionary[i] for i in xrange(plot_only)]
  plot_with_labels(low_dim_embs, labels, os.path.join(gettempdir(), 'tsne.png'))

except ImportError as ex:
  print('Please install sklearn, matplotlib, and scipy to show embeddings.')
  print(ex)
