# %%
import collections
import math
import os
import random
from tempfile import gettempdir
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf

# Step 1: Download the data.
url = 'http://mattmahoney.net/dc/'


# pylint: disable=redefined-outer-name
def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  local_filename = os.path.join(gettempdir(), filename)
  if not os.path.exists(local_filename):
    local_filename, _ = urllib.request.urlretrieve(url + filename,
                                                   local_filename)
  statinfo = os.stat(local_filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified', filename)
  else:
    print(statinfo.st_size)
    raise Exception('Failed to verify ' + local_filename +
                    '. Can you get to it with a browser?')
  return local_filename


filename = maybe_download('text8.zip', 31344016)


# Read the data into a list of strings.
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words."""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data

vocabulary = read_data(filename)
print('Data size', len(vocabulary))

# Step 2: Build the dictionary and replace rare words with UNK token.
vocabulary_size = 50000


def build_dataset(words, n_words):
  """Process raw inputs into a dataset."""
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(n_words - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    index = dictionary.get(word, 0)
    if index == 0:  # dictionary['UNK']
      unk_count += 1
    data.append(index)
  count[0][1] = unk_count
  reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  return data, count, dictionary, reversed_dictionary

# Filling 4 global variables:
# data - list of codes (integers from 0 to vocabulary_size-1).
#   This is the original text but words are replaced by their codes
# count - map of words(strings) to count of occurrences
# dictionary - map of words(strings) to their codes(integers)
# reverse_dictionary - maps codes(integers) to words(strings)
data, count, dictionary, reverse_dictionary = build_dataset(vocabulary,
                                                            vocabulary_size)
#del vocabulary  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])

data_index = 0

# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1  # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  if data_index + span > len(data):
    data_index = 0
  buffer.extend(data[data_index:data_index + span])
  data_index += span
  for i in range(batch_size // num_skips):
    context_words = [w for w in range(span) if w != skip_window]
    words_to_use = random.sample(context_words, num_skips)
    for j, context_word in enumerate(words_to_use):
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[context_word]
    if data_index == len(data):
      buffer[:] = data[:span]
      data_index = span
    else:
      buffer.append(data[data_index])
      data_index += 1
  # Backtrack a little bit to avoid skipping words in the end of a batch
  data_index = (data_index + len(data) - span) % len(data)
  return batch, labels

batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]],
        '->', labels[i, 0], reverse_dictionary[labels[i, 0]])

# Step 4: Build and train a skip-gram model.

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.
num_sampled = 64      # Number of negative examples to sample.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. These 3 variables are used only for
# displaying model accuracy, they don't affect calculation.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)


graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
  with tf.device('/cpu:0'):
    # Look up embeddings for inputs.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    nce_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Compute the average NCE loss for the batch.
  # tf.nce_loss automatically draws a new sample of the negative labels each
  # time we evaluate the loss.
  # Explanation of the meaning of NCE loss:
  #   http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/
  loss = tf.reduce_mean(
      tf.nn.nce_loss(weights=nce_weights,
                     biases=nce_biases,
                     labels=train_labels,
                     inputs=embed,
                     num_sampled=num_sampled,
                     num_classes=vocabulary_size))

  # Construct the SGD optimizer using a learning rate of 1.0.
  optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  # Compute the cosine similarity between minibatch examples and all embeddings.
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

  # Add variable initializer.
  init = tf.global_variables_initializer()

# Step 5: Begin training.
num_steps = 100001

with tf.Session(graph=graph) as session:
  # We must initialize all variables before we use them.
  init.run()
  print('Initialized')

  average_loss = 0
  for step in xrange(num_steps):
    batch_inputs, batch_labels = generate_batch(
        batch_size, num_skips, skip_window)
    feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

    # We perform one update step by evaluating the optimizer op (including it
    # in the list of returned values for session.run()
    _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += loss_val

    if step % 2000 == 0:
      if step > 0:
        average_loss /= 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step ', step, ': ', average_loss)
      average_loss = 0

    # Note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8  # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k + 1]
        log_str = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log_str = '%s %s,' % (log_str, close_word)
        print(log_str)
  final_embeddings = normalized_embeddings.eval()

# Step 6: Visualize the embeddings.


# pylint: disable=missing-docstring
# Function to draw visualization of distance between embeddings.
def plot_with_labels(low_dim_embs, labels, filename):
  assert low_dim_embs.shape[0] >= len(labels), 'More labels than embeddings'
  plt.figure(figsize=(18, 18))  # in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i, :]
    plt.scatter(x, y)
    plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')

  plt.savefig(filename)

try:
  # pylint: disable=g-import-not-at-top
  from sklearn.manifold import TSNE
  import matplotlib.pyplot as plt

  tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
  plot_only = 500
  low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
  labels = [reverse_dictionary[i] for i in xrange(plot_only)]
  plot_with_labels(low_dim_embs, labels, os.path.join(gettempdir(), 'tsne.png'))

except ImportError as ex:
  print('Please install sklearn, matplotlib, and scipy to show embeddings.')
  print(ex)
# Out:
# Found and verified text8.zip
# Data size 17005207
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']
# 3081 originated -> 5234 anarchism
# 3081 originated -> 12 as
# 12 as -> 3081 originated
# 12 as -> 6 a
# 6 a -> 12 as
# 6 a -> 195 term
# 195 term -> 2 of
# 195 term -> 6 a
# Initialized
# Average loss at step  0 :  280.977783203125
# Nearest to his: electrical, outlook, scepticism, williamite, differentiate, easily, bestiary, writable,
# Nearest to new: beets, turkestan, crowley, forman, zones, years, established, adages,
# Nearest to about: entered, platters, draper, markschies, storefront, roadster, lazarus, planing,
# Nearest to in: corporal, alston, darpa, replenish, netherland, lungs, ruthenia, lexicography,
# Nearest to be: astrakhan, goyen, counters, wheel, henceforth, lain, cedar, worthwhile,
# Nearest to s: laodiceans, perseus, rus, san, levellers, cascade, cobe, finally,
# Nearest to also: hemingway, yung, noun, postmillennialism, gliders, parliament, karloff, establish,
# Nearest to by: fantasyland, defend, takla, avatars, temperance, instrumentals, outdated, consecration,
# Nearest to which: availability, seawater, bri, reflectivity, sensations, freelance, demobilization, plugging,
# Nearest to such: deregulation, imposter, chest, haired, bursa, hoff, oddities, selecting,
# Nearest to three: thick, monopolized, valdivia, epicenter, mandela, ollie, xxxiv, vr,
# Nearest to however: milt, storefront, zeitschrift, thoracic, libretto, scanned, vel, aotearoa,
# Nearest to who: bain, mountaineer, mortis, agee, offal, shielding, sanctioning, sidney,
# Nearest to there: retina, flashpoint, punishes, farsi, hello, next, kursk, gprs,
# Nearest to one: dione, cmt, osu, bangladeshi, mineral, roofed, engenders, decreasing,
# Nearest to see: deported, grierson, honeywell, epsom, tajik, findings, betrothal, marlow,
# Average loss at step  2000 :  113.34772069549561
# Average loss at step  4000 :  52.843038011074064
# Average loss at step  6000 :  33.50337614297867
# Average loss at step  8000 :  23.511712085962294
# Average loss at step  10000 :  17.730411108136177
# Nearest to his: the, electrical, verses, south, lymphoma, differentiate, cardinality, bush,
# Nearest to new: established, preferential, ptolemy, and, eichmann, methadone, uses, zones,
# Nearest to about: entered, armor, civil, militia, hakama, defected, secret, radioactive,
# Nearest to in: and, of, on, by, for, nine, archie, to,
# Nearest to be: closely, wheel, answer, flagellates, differs, refer, shi, henceforth,
# Nearest to s: and, the, nonempty, six, of, mya, beverages, lymphoma,
# Nearest to also: cl, empire, destroying, establish, left, UNK, parliament, atheists,
# Nearest to by: in, and, eight, for, later, hayek, temperance, on,
# Nearest to which: and, lymphoma, afterwards, gb, freelance, letters, healthcare, availability,
# Nearest to such: hoff, chest, bursa, item, ep, haired, fai, bracelet,
# Nearest to three: two, six, zero, one, lymphoma, seven, jpg, nine,
# Nearest to however: recognized, monitor, cube, examination, aegean, markov, ueshiba, part,
# Nearest to who: lymphoma, ep, rs, still, var, album, meanwhile, second,
# Nearest to there: fiction, cc, ep, lymphoma, beam, next, receive, stricter,
# Nearest to one: nine, two, lymphoma, zero, UNK, mathbf, gland, eight,
# Nearest to see: marlow, deported, disasters, findings, description, wellesley, hepatitis, at,
# Average loss at step  12000 :  14.25905225455761
# Average loss at step  14000 :  11.623584336280823
# Average loss at step  16000 :  9.949597596406937
# Average loss at step  18000 :  8.529645330905915
# Average loss at step  20000 :  8.01276097381115
# Nearest to his: the, their, a, s, perl, its, vaccines, verses,
# Nearest to new: crowley, preferential, eichmann, ptolemy, and, established, circ, methadone,
# Nearest to about: entered, UNK, militia, nine, armor, monaco, hakama, integrity,
# Nearest to in: and, on, for, of, at, nine, from, by,
# Nearest to be: gemological, have, shi, refer, was, henceforth, closely, differs,
# Nearest to s: and, zero, the, of, his, mauchly, lymphoma, agouti,
# Nearest to also: destroying, and, UNK, cl, that, not, nn, establish,
# Nearest to by: was, in, for, on, with, and, vaccines, agouti,
# Nearest to which: that, and, afterwards, this, gb, lymphoma, healthcare, one,
# Nearest to such: hoff, chest, bursa, item, screenplay, ep, haired, suppress,
# Nearest to three: two, six, zero, eight, nine, seven, five, four,
# Nearest to however: and, examination, redux, but, mecklenburg, foam, ueshiba, recognized,
# Nearest to who: still, lymphoma, rs, gollancz, not, and, been, var,
# Nearest to there: fiction, he, it, hello, asimov, cc, ep, receive,
# Nearest to one: two, circ, six, nine, eight, three, four, operatorname,
# Nearest to see: marlow, grierson, zero, honeywell, deported, disasters, at, drifted,
# Average loss at step  22000 :  7.0488264524936675
# Average loss at step  24000 :  6.907782647132874
# Average loss at step  26000 :  6.732870819568634
# Average loss at step  28000 :  6.352899707078934
# Average loss at step  30000 :  5.896673139929772
# Nearest to his: their, the, its, s, asbestos, perl, verses, eredivisie,
# Nearest to new: preferential, and, crowley, eichmann, circ, ptolemy, entity, established,
# Nearest to about: roadster, militia, entered, hakama, reuptake, monaco, radioactive, integrity,
# Nearest to in: on, and, at, for, nine, from, by, of,
# Nearest to be: gemological, have, by, is, was, shi, refer, henceforth,
# Nearest to s: and, zero, two, his, the, eight, six, or,
# Nearest to also: that, never, ayahuasca, not, destroying, it, cl, discard,
# Nearest to by: in, was, with, for, as, were, on, agouti,
# Nearest to which: that, this, and, it, one, healthcare, lymphoma, dasyprocta,
# Nearest to such: screenplay, bursa, item, brian, analysing, seth, chest, ep,
# Nearest to three: six, four, seven, two, eight, five, zero, nine,
# Nearest to however: but, and, birkenau, examination, mecklenburg, redux, thoracic, recognized,
# Nearest to who: still, lymphoma, rs, he, not, she, it, been,
# Nearest to there: it, he, fiction, they, cc, asimov, ablative, inasmuch,
# Nearest to one: two, four, circ, seven, eight, dasyprocta, agouti, six,
# Nearest to see: marlow, grierson, drifted, instruction, deported, honeywell, timepieces, zero,
# Average loss at step  32000 :  5.9362956625223156
# Average loss at step  34000 :  5.673743839144707
# Average loss at step  36000 :  5.727366070151329
# Average loss at step  38000 :  5.502994522094727
# Average loss at step  40000 :  5.241760945558548
# Nearest to his: their, the, its, her, asbestos, s, perl, pies,
# Nearest to new: preferential, eichmann, circ, crowley, entity, ptolemy, four, and,
# Nearest to about: hakama, reuptake, integrity, roadster, spinoza, entered, militia, four,
# Nearest to in: on, and, at, of, from, circ, agouti, with,
# Nearest to be: have, gemological, by, was, were, refer, shi, been,
# Nearest to s: zero, and, mauchly, his, lymphoma, pig, vma, the,
# Nearest to also: never, not, that, it, which, still, ayahuasca, who,
# Nearest to by: was, in, with, agouti, were, vaccines, be, from,
# Nearest to which: that, this, it, and, what, one, lymphoma, dasyprocta,
# Nearest to such: bursa, screenplay, item, brian, known, unconnected, well, analysing,
# Nearest to three: four, six, five, seven, eight, two, zero, nine,
# Nearest to however: but, birkenau, examination, lemmy, though, mecklenburg, redux, and,
# Nearest to who: still, he, she, and, it, rs, not, lymphoma,
# Nearest to there: it, he, they, fiction, retina, inasmuch, instrumentation, aba,
# Nearest to one: two, four, eight, seven, three, six, five, circ,
# Nearest to see: marlow, grierson, zero, drifted, instruction, vacancy, but, deported,
# Average loss at step  42000 :  5.416212419271469
# Average loss at step  44000 :  5.257352979302406
# Average loss at step  46000 :  5.217201221227646
# Average loss at step  48000 :  5.237770881056786
# Average loss at step  50000 :  4.985360707998276
# Nearest to his: their, the, its, her, s, pies, them, asbestos,
# Nearest to new: preferential, eichmann, circ, entity, crowley, ptolemy, lifestyles, ced,
# Nearest to about: hakama, reuptake, integrity, spinoza, roadster, armor, rank, militia,
# Nearest to in: on, at, of, for, kapoor, from, circ, agouti,
# Nearest to be: have, gemological, was, by, is, refer, been, are,
# Nearest to s: his, and, zero, of, mauchly, circ, the, vma,
# Nearest to also: never, which, still, not, it, often, who, now,
# Nearest to by: was, with, in, from, agouti, be, vaccines, were,
# Nearest to which: that, this, and, it, what, one, also, two,
# Nearest to such: franchisee, bursa, well, known, screenplay, item, debuts, unconnected,
# Nearest to three: four, six, seven, five, two, eight, one, circ,
# Nearest to however: but, and, birkenau, though, while, lemmy, examination, mecklenburg,
# Nearest to who: he, still, and, she, not, also, which, lymphoma,
# Nearest to there: it, he, they, fiction, and, now, retina, aba,
# Nearest to one: two, four, five, three, six, seven, eight, circ,
# Nearest to see: marlow, grierson, drifted, vacancy, instruction, but, blight, timepieces,
# Average loss at step  52000 :  5.021743372917175
# Average loss at step  54000 :  5.181206092238426
# Average loss at step  56000 :  5.023077035069465
# Average loss at step  58000 :  5.041247672080994
# Average loss at step  60000 :  4.935348357319832
# Nearest to his: their, its, her, the, s, our, pies, exalted,
# Nearest to new: preferential, eichmann, entity, lifestyles, circ, and, ced, ursus,
# Nearest to about: hakama, six, reuptake, spinoza, integrity, roadster, rank, sorrow,
# Nearest to in: on, and, from, ursus, at, with, of, during,
# Nearest to be: have, by, been, gemological, was, refer, are, were,
# Nearest to s: mauchly, his, zero, ursus, circ, michelob, vma, five,
# Nearest to also: which, never, still, it, that, often, who, not,
# Nearest to by: was, be, with, agouti, as, kapoor, from, vaccines,
# Nearest to which: that, this, what, it, also, one, but, and,
# Nearest to such: well, franchisee, bursa, known, many, screenplay, debuts, unconnected,
# Nearest to three: four, five, two, six, eight, seven, one, ursus,
# Nearest to however: but, while, and, birkenau, though, examination, lemmy, when,
# Nearest to who: he, still, which, she, they, also, not, often,
# Nearest to there: it, they, he, fiction, now, aba, retina, still,
# Nearest to one: two, four, three, five, six, circ, kapoor, eight,
# Nearest to see: marlow, grierson, blight, but, instruction, timepieces, zero, drifted,
# Average loss at step  62000 :  4.997604100704193
# Average loss at step  64000 :  4.853617843389511
# Average loss at step  66000 :  4.615569187879562
# Average loss at step  68000 :  4.982601952195168
# Average loss at step  70000 :  4.897454003214836
# Nearest to his: their, her, its, the, s, our, exalted, them,
# Nearest to new: eichmann, preferential, entity, circ, lifestyles, callithrix, auctioned, ursus,
# Nearest to about: hakama, verdeans, four, rank, reuptake, spinoza, lazarus, integrity,
# Nearest to in: circ, ursus, on, at, microcebus, and, kapoor, from,
# Nearest to be: been, have, by, are, were, gemological, refer, was,
# Nearest to s: mauchly, his, zero, pig, and, ursus, has, nonempty,
# Nearest to also: never, which, still, often, now, below, usually, it,
# Nearest to by: be, was, with, as, agouti, during, in, were,
# Nearest to which: that, this, it, also, what, but, and, mideast,
# Nearest to such: well, known, these, franchisee, bursa, many, certain, debuts,
# Nearest to three: six, four, five, two, eight, seven, nine, ursus,
# Nearest to however: but, while, and, though, when, birkenau, although, examination,
# Nearest to who: he, still, she, which, often, they, also, and,
# Nearest to there: it, they, he, thaler, fiction, now, aba, still,
# Nearest to one: six, two, four, five, three, eight, microcebus, kapoor,
# Nearest to see: marlow, grierson, blight, but, instruction, mico, hutu, vacancy,
# Average loss at step  72000 :  4.745217482805252
# Average loss at step  74000 :  4.793719613075257
# Average loss at step  76000 :  4.724755262136459
# Average loss at step  78000 :  4.799689041674137
# Average loss at step  80000 :  4.785706982135773
# Nearest to his: their, her, its, the, our, s, exalted, chaosium,
# Nearest to new: eichmann, preferential, circ, entity, turkestan, mitral, callithrix, lifestyles,
# Nearest to about: hakama, four, verdeans, rank, reuptake, lazarus, spinoza, truro,
# Nearest to in: ursus, at, circ, microcebus, on, kapoor, during, kosar,
# Nearest to be: been, have, by, were, refer, gemological, are, is,
# Nearest to s: his, mauchly, ursus, michelob, zero, circ, pig, microcebus,
# Nearest to also: never, which, still, often, now, below, usually, it,
# Nearest to by: was, were, be, with, during, from, agouti, as,
# Nearest to which: that, this, it, what, also, mideast, and, but,
# Nearest to such: well, these, known, many, franchisee, certain, bursa, debuts,
# Nearest to three: four, five, two, six, seven, eight, kapoor, one,
# Nearest to however: but, while, though, although, when, and, birkenau, examination,
# Nearest to who: he, still, she, they, which, often, rs, mitral,
# Nearest to there: it, they, he, now, thaler, fiction, which, still,
# Nearest to one: seven, six, two, four, eight, five, microcebus, three,
# Nearest to see: grierson, marlow, but, blight, mico, vacancy, rearmament, call,
# Average loss at step  82000 :  4.760366704940796
# Average loss at step  84000 :  4.756906368255615
# Average loss at step  86000 :  4.773798263907432
# Average loss at step  88000 :  4.749534687399864
# Average loss at step  90000 :  4.7332314701080325
# Nearest to his: their, her, its, the, s, our, exalted, pies,
# Nearest to new: eichmann, circ, callithrix, mitral, preferential, thaler, turkestan, ursus,
# Nearest to about: hakama, rank, verdeans, peacocks, reuptake, spinoza, truro, integrity,
# Nearest to in: during, ursus, on, circ, at, microcebus, and, archie,
# Nearest to be: been, have, are, were, by, gemological, refer, is,
# Nearest to s: his, ursus, microcebus, circ, pig, mauchly, wraith, nonempty,
# Nearest to also: never, still, which, often, now, below, usually, it,
# Nearest to by: was, as, be, were, with, agouti, from, during,
# Nearest to which: that, this, what, it, also, but, mideast, who,
# Nearest to such: well, these, known, many, certain, some, franchisee, debuts,
# Nearest to three: four, five, six, two, seven, eight, one, nine,
# Nearest to however: but, while, although, though, when, birkenau, that, ursus,
# Nearest to who: he, she, still, they, often, which, and, there,
# Nearest to there: it, they, he, now, thaler, we, fiction, often,
# Nearest to one: two, four, seven, three, six, eight, five, microcebus,
# Nearest to see: marlow, grierson, but, blight, call, vacancy, hutu, mico,
# Average loss at step  92000 :  4.669682058930397
# Average loss at step  94000 :  4.716669698119164
# Average loss at step  96000 :  4.7004385641813275
# Average loss at step  98000 :  4.595352462887764
# Average loss at step  100000 :  4.684559970140457
# Nearest to his: their, her, its, the, s, our, my, exalted,
# Nearest to new: eichmann, constituci, preferential, turkestan, entity, circ, lifestyles, mitral,
# Nearest to about: verdeans, hakama, rank, peacocks, spinoza, integrity, only, four,
# Nearest to in: during, at, ursus, on, constituci, circ, kapoor, microcebus,
# Nearest to be: been, have, refer, by, were, are, was, gemological,
# Nearest to s: his, ursus, microcebus, wraith, vma, five, circ, kapoor,
# Nearest to also: never, which, often, still, now, below, usually, it,
# Nearest to by: was, be, as, with, agouti, vaccines, were, eight,
# Nearest to which: that, this, what, also, it, but, mideast, and,
# Nearest to such: well, these, known, many, certain, some, babysitter, peacocks,
# Nearest to three: five, four, six, seven, two, eight, ursus, nine,
# Nearest to however: but, while, although, though, when, birkenau, that, which,
# Nearest to who: he, she, still, often, they, and, which, also,
# Nearest to there: they, it, he, now, thaler, we, often, fiction,
# Nearest to one: seven, six, two, four, five, three, eight, microcebus,
# Nearest to see: marlow, grierson, constituci, but, blight, callithrix, call, mico,
